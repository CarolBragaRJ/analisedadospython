# %%
# importando as bibliotecas
import pandas as pd

#informa ao matplotlib sobre graficos inline
# %matplotlib inline

# %%
# carregar o arquivo csv
df = pd.read_csv('sia112018.csv', sep =';', encoding = 'cp1252')

# trocar o nome das colunas
# df.columns

# exibir as primeiras linhas
df.head (10)
# Out:
#    ano_mes  cod_estabelecimento_cnes              estabelecimento_cnes  \
# 0   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 1   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 2   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 3   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 4   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 5   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 6   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 7   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 8   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
# 9   201811                   2816741  FARMACIA DE ALTO CUSTO - ASA SUL
#
#         complexidade  cod_grupo              grupo  cod_subgrupo  \
# 0  Alta complexidade          6  06 - Medicamentos           604
# ...

# %%
# descrever as colunas
df.describe ()
# Out:
#         ano_mes  cod_estabelecimento_cnes      cod_grupo   cod_subgrupo  \
# count  180282.0              1.802820e+05  180282.000000  180282.000000
# mean   201811.0              2.711795e+06       3.355121     338.785325
# std         0.0              3.261024e+06       1.631517     163.201566
# min    201811.0              1.045600e+04       1.000000     101.000000
# 25%    201811.0              1.049900e+04       2.000000     203.000000
# 50%    201811.0              1.137100e+04       3.000000     301.000000
# 75%    201811.0              5.717515e+06       5.000000     501.000000
# max    201811.0              9.620338e+06       8.000000     803.000000
#
#        cod_procedimento     quantidade  cod_carater_atendimento  \
# count      1.802820e+05  180282.000000            180282.000000
# mean       3.388762e+08      17.953717                22.030918
# std        1.633118e+08     224.910496                40.205553
# ...

# %%
# listar a quantidade de consultas unicas
df['estabelecimento_cnes'].unique
# Out:
# <bound method Series.unique of 0                     FARMACIA DE ALTO CUSTO - ASA SUL
# 1                     FARMACIA DE ALTO CUSTO - ASA SUL
# 2                     FARMACIA DE ALTO CUSTO - ASA SUL
# 3                     FARMACIA DE ALTO CUSTO - ASA SUL
# 4                     FARMACIA DE ALTO CUSTO - ASA SUL
# 5                     FARMACIA DE ALTO CUSTO - ASA SUL
# 6                     FARMACIA DE ALTO CUSTO - ASA SUL
# 7                     FARMACIA DE ALTO CUSTO - ASA SUL
# 8                     FARMACIA DE ALTO CUSTO - ASA SUL
# 9                     FARMACIA DE ALTO CUSTO - ASA SUL
# 10                    FARMACIA DE ALTO CUSTO - ASA SUL
# 11                    FARMACIA DE ALTO CUSTO - ASA SUL
# 12                    FARMACIA DE ALTO CUSTO - ASA SUL
# 13                    FARMACIA DE ALTO CUSTO - ASA SUL
# 14                    FARMACIA DE ALTO CUSTO - ASA SUL
# 15                    FARMACIA DE ALTO CUSTO - ASA SUL
# 16                    FARMACIA DE ALTO CUSTO - ASA SUL
# ...

# %%
# quantidade de consultas por estabelecimento
df['estabelecimento_cnes'].value_counts()
# Out:
# HOSPITAL MATERNO INFANTIL DE BRASILIA - HMIB        18929
# FARMACIA DE ALTO CUSTO - CEILANDIA                  15693
# INSTITUTO HOSPITAL DE BASE DO DISTRITO FEDERAL      15191
# FARMACIA DE ALTO CUSTO - ASA SUL                    13876
# HRT HOSPITAL REGIONAL DE TAGUATINGA                 11156
# HOSPITAL UNIVERSITARIO DE BRASILIA                  11050
# HOSPITAL REGIONAL DE CEILANDIA                       9754
# FARMACIA DE ALTO CUSTO GAMA                          8829
# HRAN                                                 6265
# HRG                                                  5496
# HRL                                                  4131
# HRS                                                  3766
# IDR SAMAMBAIA SERVICOS MEDICOS                       3714
# INSTITUTO DE CARDIOLOGIA DO DISTRITO FEDERAL         3709
# HRSM                                                 3537
# HOSPITAL DA CRIANCA DE BRASILIA JOSE ALENCAR-HCB     3250
# ...

# %%
# plotar o grafico por estabelcimento aula 1:49:34
df['estabelecimento_cnes'].value_counts().plot.bar()
